# %%
import pandas as pd 
import numpy as np
import json
import os
from datetime import datetime

# %%
file_array = []
dates = []


for file in os.listdir("/Users/anthony/Desktop/slipping-and-sliding/all-exchanges/"):
    if file.endswith("binance_orderbook.json"):
        file_array.append(os.path.join("/Users/anthony/Desktop/slipping-and-sliding/all-exchanges/", file))


for file in file_array:
    date = file.split('/')[6].split('_')[0]
    dates.append(date)

# %%
slippage = []
slippage_pairs = []
currencies = []

for index, file in enumerate(file_array):
    print(file)
    try:
        with open(file, encoding='utf-8') as data_file:
            dataset = json.loads(data_file.read())
        for pair in dataset: 
            if (len(dataset[pair]['asks']) > 5 and len(dataset[pair]['bids']) > 5):
                currency = {}
                currency['Pair'] = pair
                currency['Asks'] = dataset[pair]['asks']
                currency['Bids'] = dataset[pair]['bids']
                currency['Date'] = dates[index]
                currencies.append(currency)
    except:
        continue


        
df = pd.DataFrame(currencies)

pair_dict = {}


for pair, value in dict(df['Pair'].value_counts()).items():
    trading_currency = pair.split('/')[1]
    if trading_currency in pair_dict.keys():
        pair_dict[trading_currency] += value 
    else:
        pair_dict[trading_currency] = value

pair_dict

sorted(pair_dict.items(), key=lambda x: x[0])


#assume PAX TUSD USDC USDS USDT are 1 to 1 

#Find How much BNB BTC ETH XRP you can get for 10k USD

bitcoin_prices_in_usd = {}
eth_prices_in_usd = {}
bnb_prices_in_usd = {}
xrp_prices_in_usd = {}


for entry in currencies:
    if entry['Pair'] == 'BTC/USDT':
        bitcoin_prices_in_usd[(entry['Date'])] = (entry['Asks'][0][0] + entry['Bids'][0][0]) / 2
    if entry['Pair'] == 'ETH/USDT':
        eth_prices_in_usd[(entry['Date'])] = (entry['Asks'][0][0] + entry['Bids'][0][0]) / 2
    if entry['Pair'] == 'BNB/USDT':
        bnb_prices_in_usd[(entry['Date'])] = (entry['Asks'][0][0] + entry['Bids'][0][0]) / 2
    if entry['Pair'] == 'XRP/USDT':
        xrp_prices_in_usd[(entry['Date'])] = (entry['Asks'][0][0] + entry['Bids'][0][0]) / 2

def calc_slippage_asks(asks, amount):
    starting_amount = amount
    asking_price = asks[0][0]
    index = 0
    while starting_amount > 0:
        try:
            amount = asks[index][0] * asks[index][1]
            if starting_amount - amount < 0:
                break
            else:
                index +=1
        except:
            return 100

    return (asks[index][0] - asking_price) / asking_price


def calc_slippage_bids(bids, amount):
    starting_amount = amount
    bid_price = bids[0][0]
    index = 0
    while starting_amount > 0:
        try:
            amount = bids[index][0] * bids[index][1]
            if starting_amount - amount < 0:
                break
            else:
                index +=1
        except:
            return 100
    return (bids[index][0] - bid_price) / bid_price * 100


def calc_total_order_book_depth(date, bids_or_asks, pair):
    base_currency = pair.split('/')[1]
    total_depth = 0
    for bid_or_ask in bids_or_asks:
        if base_currency == 'BTC':
            total_depth += (bid_or_ask[0] * bitcoin_prices_in_usd[date] * bid_or_ask[1])
        elif base_currency == 'XRP':
            total_depth += (bid_or_ask[0] * xrp_prices_in_usd[date] * bid_or_ask[1])
        elif base_currency == 'BNB':
            total_depth += (bid_or_ask[0] * bnb_prices_in_usd[date] * bid_or_ask[1])
        elif base_currency == 'ETH':
            total_depth += (bid_or_ask[0] * eth_prices_in_usd[date] * bid_or_ask[1])
        else:
            total_depth += (bid_or_ask[0] * bid_or_ask[1])
    return total_depth

def calc_bid_ask_spread(bids, asks):
    spread = asks[0][0] - bids[0][0]
    percentage_spread = (spread / asks[0][0]) * 100
    return percentage_spread
# Out:
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551627357881_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551695146658_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552065980946_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552107331032_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551691387119_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551433626740_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552174953488_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552156177826_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551478301522_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552111083524_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551672586518_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551774300395_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551353650312_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552069744264_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551482274077_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551649977558_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551725341359_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551405380709_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551521249080_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551868395029_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551883435872_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551608090241_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551494208281_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552171202798_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551318452211_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551486220963_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551413367716_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552126108963_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551702689398_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552088548964_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551687626109_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551333924687_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551568382632_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551759268469_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551668828256_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551755501885_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551736629845_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552096063346_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551505870356_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551683867781_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551572284823_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552163701839_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552167452877_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551462673970_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552133618365_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551815691537_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551781812935_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551604228964_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552122354349_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551615900775_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551349675470_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551845849990_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551345701369_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551732868568_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552081020948_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551310847921_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551381736054_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552141130951_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551417372372_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552148652956_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551804386682_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551580181703_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551556735762_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551638684040_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551377776254_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551307083656_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551337824108_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551646205350_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551584107982_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551401412535_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551793089803_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551838335394_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551710239092_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551864635541_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551770542119_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551819553323_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551421428148_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551611993185_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552084781659_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551661289611_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551860881103_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552129863094_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551875912163_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551513501596_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551879671010_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552137374021_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551429514334_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551811930702_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552103574984_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552118598487_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551576224383_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551634905971_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551857123762_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551498069197_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551823307006_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551365730909_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551532996963_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551564477708_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551751740385_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551540907547_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551744195033_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551560577800_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551849606691_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551653736458_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551721564842_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551303127119_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551517358091_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551729105288_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551501945287_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551740390436_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551470495818_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551778063975_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551619829708_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551536946909_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551529031809_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551458685191_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551872154675_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551830821622_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551623588703_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551474360481_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551665057079_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552152421208_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551800622907_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551796859691_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552062221742_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551446667651_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551314617542_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551409364964_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551552778119_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551657493460_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551357668057_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551397456279_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551389555485_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551442506895_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551789327669_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551322300495_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551385615010_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551890961210_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551299144200_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551842091900_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551642439897_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552077260855_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551763029554_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551680108560_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552144892309_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551706448398_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551676346354_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552114836678_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551450810263_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551330039641_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551466660110_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551361689970_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551490206355_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551887196683_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552159938993_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551631128355_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551544897652_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551600185257_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551785568679_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551437739965_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551393525240_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551525137539_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551717783779_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551548886653_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551592134852_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551588118830_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551425396665_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551509655119_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552099815598_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551747960619_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551894722648_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551369730119_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551714023444_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551326161134_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551853363423_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551373763390_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551834577475_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551827063197_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551766787709_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551454713407_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551698912032_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551596146620_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551808160391_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1551341758364_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552073504133_binance_orderbook.json
# /Users/anthony/Desktop/slipping-and-sliding/all-exchanges/1552092304327_binance_orderbook.json

# %%
final_currencies = []

for index, currency in enumerate(currencies):
    currency_dict = {}
    bid_ask_spread = calc_bid_ask_spread(currency['Bids'], currency['Asks'])
    currency_dict['bid_ask_spread'] = bid_ask_spread
    currency_dict['date'] = currency['Date']
    currency_dict['pair'] = currency['Pair']
    currency_dict['ask_depth'] = calc_total_order_book_depth(currency['Date'], currency['Asks'],currency['Pair'])
    currency_dict['bid_depth'] = calc_total_order_book_depth(currency['Date'], currency['Bids'], currency['Pair'])
    final_currencies.append(currency_dict)



        
def convert_cmc_to_binance(row):
    if row.split('/')[0] == 'BCHABC':
        return 'BCH' + '/' + row.split('/')[1]
    elif row.split('/')[0] == 'BCHSV':
        return 'BSV' + '/' + row.split('/')[1]
    elif row.split('/')[0] == 'YOYO':
        return 'YOYOW' + '/' + row.split('/')[1]
    else:
        return row

volume_dict = {}

df_rank = pd.read_csv('/users/anthony/desktop/slipping-and-sliding/all-exchanges/volume_rank.csv')

spread_df = pd.DataFrame(final_currencies)

# %%
final_df = pd.merge(spread_df, df_rank, left_on='pair', right_on='pair', how='left')

final_df['total_order_depth'] = final_df['ask_depth'] + final_df['bid_depth']

median_df_rank = pd.DataFrame(final_df.groupby('pair').median()['total_order_depth'].rank(ascending=False).sort_values()).reset_index()

median_df_rank.columns = ['pair','median rank']

last_df = pd.merge(final_df, median_df_rank, left_on='pair', right_on='pair')




last_df.groupby('volume_rank').median()['bid_ask_spread'].plot()

# %%
# Out:
#             ask_slippage   bid_slippage
# Pair
# BTT/BTC         0.000000       0.000000
# USDS/PAX        0.000024       0.000024
# USDS/USDC       0.000059       0.000059
# USDS/TUSD       0.000237       0.000237
# NPXS/BTC        0.000617       0.000617
# USDC/PAX        0.000682       0.000682
# BTC/PAX         0.000851       0.000851
# TUSD/USDT       0.000918       0.000918
# BTC/USDT        0.001148       0.001148
# USDC/USDT       0.001465       0.001465
# HOT/BTC         0.001522       0.001522
# VET/BTC         0.001697       0.001697
# PAX/USDT        0.001887       0.001887
# DENT/BTC        0.001892       0.001892
# BTC/USDC        0.002040       0.002040
# TRX/BTC         0.002492       0.002492
# BCH/TUSD        0.002806       0.002806
# SC/BTC          0.002822       0.002822
# MFT/BTC         0.003325       0.003325
# EOS/USDT        0.003521       0.003521
# EOS/ETH         0.003715       0.003715
# EOS/BTC         0.004445       0.004445
# NCASH/BTC       0.005258       0.005258
# XRP/USDT        0.005359       0.005359
# LTC/USDT        0.006621       0.006621
# ADA/BTC         0.007763       0.007763
# KEY/BTC         0.008123       0.008123
# TRX/USDT        0.012135       0.012135
# ADA/USDT        0.013649       0.013649
# STORM/BTC       0.021896       0.021896
# ...                  ...            ...
# GRS/ETH       100.000000     100.000000
# PHX/ETH       100.000000     100.000000
# GRS/BTC       100.000000     100.000000
# PIVX/BTC      100.000000     100.000000
# PIVX/ETH      100.000000     100.000000
# POA/BNB       100.000000     100.000000
# POA/BTC       100.000000     100.000000
# FUN/ETH       100.000000     100.000000
# POA/ETH       100.000000     100.000000
# GNT/ETH       100.000000     100.000000
# ZRX/ETH       100.000000     100.000000
# POE/ETH       100.000000     100.000000
# QKC/ETH       100.000000     100.000000
# GAS/BTC       100.000000     100.000000
# PPT/ETH       100.000000     100.000000
# POWR/ETH      100.000000     100.000000
# GNT/BNB       100.000000     100.000000
# PPT/BTC       100.000000     100.000000
# POWR/BNB      100.000000     100.000000
# POLY/BNB      100.000000     100.000000
# BSV/USDC      767.551271     767.551271
# LTC/USDC     1437.006837    1437.006837
# LTC/PAX      2126.547377    2126.547377
# THETA/BNB    2611.934746    2611.934746
# AGI/BNB     15996.371713   15996.371713
# LINK/USDC   20510.526893   20510.526893
# LINK/TUSD   23372.788764   23372.788764
# LINK/PAX    23388.326971   23388.326971
# CVC/BNB    123825.523673  123825.523673
# NXS/BNB    363498.358802  363498.358802
#
# [433 rows x 2 columns]
